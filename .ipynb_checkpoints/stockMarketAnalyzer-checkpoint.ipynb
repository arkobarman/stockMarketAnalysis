# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from APIs import goldenAndDeathCross as gdc

companyName = 'GOOG'

# %%
# stockHistoryFr = pd.read_csv(os.path.join('data', '{}.csv'.format(companyName)))
# dateList = stockHistoryFr['Date'].to_list()
# openList = stockHistoryFr['Open'].to_list()
# highList = stockHistoryFr['High'].to_list()
# lowList = stockHistoryFr['Low'].to_list()
# closeList = stockHistoryFr['Close'].to_list()

# %% [markdown]
# # Golden cross and/or death cross detection

# %%
gdc.analyzeGoldenAndDeathCross('AMZN', nDays_short=50, nDays_long=100)
